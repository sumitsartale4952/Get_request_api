# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e814f43234b4395bfca3a4d827a5e857&language=en-US&page=1')

# %%
temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df
# Out:
#         id                                   title  \
# 0    22821  The Boondock Saints II: All Saints Day
# 1   355506                                   Siren
# 2   183662                                   Crush
# 3    49953     A Turtle's Tale: Sammy's Adventures
# 4    41439                                  Saw 3D
# 5    15516              The Last House on the Left
# 6    11847                      The Accidental Spy
# 7    10680                    D3: The Mighty Ducks
# 8     9564         Asterix & Obelix Take on Caesar
# 9   253626                               Good Kill
# 10  446131                                  Madame
# 11  254193                             Late Phases
# 12   38780                                 Rampage
# 13    1642                                 The Net
# 14  454699                          Monster Family
# 15  138697                                 Don Jon
# 16   10900                            Surveillance
# ...

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1,429):
        response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e814f43234b4395bfca3a4d827a5e857&language=en-US&page={}'.format(i))
        temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
        df = df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\ssart\AppData\Local\Temp\ipykernel_25996\774396599.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ssart\AppData\Local\Temp\ipykernel_25996\774396599.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ssart\AppData\Local\Temp\ipykernel_25996\774396599.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ssart\AppData\Local\Temp\ipykernel_25996\774396599.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#            id                     title  \
# 0         238             The Godfather
# 1         278  The Shawshank Redemption
# 2      772071          Cuando Sea Joven
# 3         240     The Godfather Part II
# 4         424          Schindler's List
# ...       ...                       ...
# 17115  138697                   Don Jon
# 17116   10900              Surveillance
# 17117   10640               Futureworld
# 17118    4256             Scary Movie 3
# 17119  934756         Love in the Villa
#
#                                                 overview release_date  \
# 0      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1      Framed in the 1940s for the double murder of h...   1994-09-23
# 2      70-year-old Malena gets a second chance at lif...   2022-09-14
# 3      In the continuing saga of the Corleone crime f...   1974-12-20
# 4      The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df.to_csv('movies.csv')
